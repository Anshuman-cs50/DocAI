# %%
# !pip install --quite google-genai
# Out:
# Usage:
#   pip install [options] <requirement specifier> [package-index-options] ...
#   pip install [options] -r <requirements file> [package-index-options] ...
#   pip install [options] [-e] <vcs project url> ...
#   pip install [options] [-e] <local project path> ...
#   pip install [options] <archive url/path> ...
#
# no such option: --quite

# %%
import os
from google import genai
# Set your API key
os.environ["API_KEY"] = "AIzaSyCfvPpW59SO34pQjg5euITfaqvf_0Lz-EI"
client = genai.Client(api_key=os.environ["API_KEY"])

# %%
response = client.models.generate_content(
   model="gemini-2.0-flash", # Specify the model
   contents="What is the meaning of life?"
)
print(response.text)

# %%
response = [{'input_text': [{'role': 'user',
    'content': [{'type': 'text',
      'text': 'I am having a sore throat, what should i do?'}]}],
  'generated_text': [{'role': 'user',
    'content': [{'type': 'text',
      'text': 'I am having a sore throat, what should i do?'}]},
   {'role': 'assistant',
    'content': "Okay, a sore throat is no fun! Here's a breakdown of what you can do to manage it, ranging from simple home remedies to when you should see a doctor:\n\n**1. Home Remedies (for mild to moderate sore throats):**\n\n*   **Rest:** Give your body a chance to recover. Avoid strenuous activities.\n*   **Hydration:** Drink plenty of fluids. Water is best, but you can also try:\n    *   Warm tea (especially with honey and lemon)\n    *   Broth\n    *   Juice (avoid acidic juices like orange juice, which can irritate the throat)\n    *   Electrolyte drinks (if you're feeling dehydrated)\n*   **Soothing Foods:**\n    *   Soft foods that are easy to swallow (soup, yogurt, mashed potatoes, oatmeal)\n    *   Cold foods (ice pops, ice cream) can sometimes provide relief.\n*   **Gargle with Salt Water:** Dissolve 1/2 teaspoon of salt in 8 ounces of warm water and gargle for 30 seconds several times a day. This can help reduce inflammation and clear mucus.\n*   **Lozenges and Hard Candies:** These stimulate saliva"}]}]

print(response[0]['generated_text'][1]['content'])
# Out:
# Okay, a sore throat is no fun! Here's a breakdown of what you can do to manage it, ranging from simple home remedies to when you should see a doctor:
#
# **1. Home Remedies (for mild to moderate sore throats):**
#
# *   **Rest:** Give your body a chance to recover. Avoid strenuous activities.
# *   **Hydration:** Drink plenty of fluids. Water is best, but you can also try:
#     *   Warm tea (especially with honey and lemon)
#     *   Broth
#     *   Juice (avoid acidic juices like orange juice, which can irritate the throat)
#     *   Electrolyte drinks (if you're feeling dehydrated)
# *   **Soothing Foods:**
#     *   Soft foods that are easy to swallow (soup, yogurt, mashed potatoes, oatmeal)
#     *   Cold foods (ice pops, ice cream) can sometimes provide relief.
# *   **Gargle with Salt Water:** Dissolve 1/2 teaspoon of salt in 8 ounces of warm water and gargle for 30 seconds several times a day. This can help reduce inflammation and clear mucus.
# ...

# %% [markdown]
# Okay, a sore throat is no fun! Here's a breakdown of what you can do to manage it, ranging from simple home remedies to when you should see a doctor:
#
# **1. Home Remedies (for mild to moderate sore throats):**
#
# *   **Rest:** Give your body a chance to recover. Avoid strenuous activities.
# *   **Hydration:** Drink plenty of fluids. Water is best, but you can also try:
#     *   Warm tea (especially with honey and lemon)
#     *   Broth
#     *   Juice (avoid acidic juices like orange juice, which can irritate the throat)
#     *   Electrolyte drinks (if you're feeling dehydrated)
# *   **Soothing Foods:**
#     *   Soft foods that are easy to swallow (soup, yogurt, mashed potatoes, oatmeal)
#     *   Cold foods (ice pops, ice cream) can sometimes provide relief.
# *   **Gargle with Salt Water:** Dissolve 1/2 teaspoon of salt in 8 ounces of warm water and gargle for 30 seconds several times a day. This can help reduce inflammation and clear mucus.
# *   **Lozenges and Hard Candies:** These stimulate saliva
